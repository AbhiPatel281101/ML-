# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv("CustomersTransactions2021.csv")
df.head()
# Out:
#    customer_id  id txn_type  txn_total       Customers  Products Province  \
# 0         1001   1    Debit     165.78  Johnny Awesome         3       ON
# 1         1001   2   Credit      42.10  Johnny Awesome         3       ON
# 2         1001   4   Credit     103.03  Johnny Awesome         3       ON
# 3         1001   5   Credit      56.60  Johnny Awesome         3       ON
# 4         1002   6    Debit     214.34      Bob Marley         4       ON
#
#    Relationship          Category
# 0             1            wealth
# 1             1            wealth
# 2             1            wealth
# 3             1            wealth
# 4             1  personal_banking

# %%
df.columns
# Out:
# Index(['customer_id', 'id', 'txn_type', 'txn_total', 'Customers', 'Products',
#        'Province', 'Relationship', 'Category'],
#       dtype='object')

# %% [markdown]
# #id columns has values not shorted missing at random

# %%
df.rename(columns ={'id':'txn_id'},inplace = True)

# %%
df.columns
# Out:
# Index(['customer_id', 'txn_id', 'txn_type', 'txn_total', 'Customers',
#        'Products', 'Province', 'Relationship', 'Category'],
#       dtype='object')

# %%
df.sort_values(by='txn_id',inplace=True)

# %%
#line graph:
plt.plot(df['txn_id'],df['txn_total'])
plt.title("Line graph")
plt.xlabel("Txn_ID")
plt.ylabel("Txn_amount in $")
# Out:
# Text(0, 0.5, 'Txn_amount in $')

# %%
#line graph:
#with out plt.legend() we can not print label="Transaction_Dollars"
plt.plot(df['txn_id'],df['txn_total'],'r--o',label="Transaction_Dollars")
plt.title("Line graph")
plt.xlabel("Txn_ID")
plt.ylabel("Txn_amount in $")
plt.legend()

# %%
#line graph:
#change ylabel verticaly rotation=0,labelpad =40
#change with of x by plt.figure(figsize =(15,5))

plt.figure(figsize =(15,5))

plt.plot(df['txn_id'],df['txn_total'],'r--o',label="Transaction_Dollars")
plt.title("Line graph")
plt.xlabel("Txn_ID")
plt.ylabel("Txn_amount in $",rotation=0,labelpad =40)
plt.legend()

# %%
# For the above graph , annotate every point with its corresponding TxnAmount:
#plt.annotate() allocate values to each poins 
plt.figure(figsize =(15,5))

plt.plot(df['txn_id'],df['txn_total'],'r--o',label="Transaction_Dollars")
plt.title("Line graph")
plt.xlabel("Txn_ID")
plt.ylabel("Txn_amount in $",rotation=0,labelpad =40)
plt.legend()

for x,y in zip(df['txn_id'], df['txn_total']):
    label = "{:.2f}".format(y)
    plt.annotate(label,(x,y))

# %%
plt.hist(df['txn_total'], bins =10)
# Out:
# (array([4., 4., 3., 4., 4., 6., 2., 2., 3., 2.]),
#  array([  5.92 ,  50.267,  94.614, 138.961, 183.308, 227.655, 272.002,
#         316.349, 360.696, 405.043, 449.39 ]),
#  <BarContainer object of 10 artists>)

# %%
counts,limits.plt.hist(df['txn_total'], bins =10)
# Out:
# (array([4., 4., 3., 4., 4., 6., 2., 2., 3., 2.]),
#  array([  5.92 ,  50.267,  94.614, 138.961, 183.308, 227.655, 272.002,
#         316.349, 360.696, 405.043, 449.39 ]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20380\3332347545.py in ?()
# ----> 1 df.counts
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'counts'

# %%
df['Customers'].unique()
# Out:
# array(['Johnny Awesome', 'Bob Marley', 'Taylor Swift', 'Stephen Smith',
#        'Delilah Avery', 'Johnson Cory', 'Maria Alva', 'Jessica Fast',
#        'Mariah Anita Smith', 'Robert Optimus', 'Steven Prime',
#        'Stephanie Element'], dtype=object)

# %%
fig , ((ax1,ax2,ax3) , (ax4,ax5,ax6)) = plt.subplots(2,3,sharex = True, sharey = True,figsize = (10,4))

# %%
df[df["Customers"] == "Johnny Awesome"]
# Out:
#    customer_id  txn_id txn_type  txn_total       Customers  Products Province  \
# 0         1001       1    Debit     165.78  Johnny Awesome         3       ON
# 1         1001       2   Credit      42.10  Johnny Awesome         3       ON
# 2         1001       4   Credit     103.03  Johnny Awesome         3       ON
# 3         1001       5   Credit      56.60  Johnny Awesome         3       ON
#
#    Relationship Category
# 0             1   wealth
# 1             1   wealth
# 2             1   wealth
# 3             1   wealth

# %%
fig, ((ax1,ax2,ax3),(ax4,ax5,ax6))=plt.subplots(2,3, sharex = True, sharey = True, figsize =(10,4))

ax1.plot(df[df["Customers"] == "Johnny Awesome"]["txn_id"], df[df["Customers"] == "Johnny Awesome"]["txn_total"], 'r--*')

ax1.set_title("Johnny Awesome spending")
ax1.set_xlabel("txn_id")
ax1.set_ylabel("txn_amount")
ax2.plot(df[df["Customers"] == "Bob Marley"]["txn_id"], df[df["Customers"] == "Bob Marley"]["txn_total"], 'g--*')

ax2.set_title("Johnny Awesome spending")
ax2.set_xlabel("txn_id")
ax2.set_ylabel("txn_amount")
ax3.plot(df[df["Customers"] == "Taylor Swift"]["txn_id"], df[df["Customers"] == "Taylor Swift"]["txn_total"], 'r--*')

ax3.set_title("Taylor Swift spending")
ax3.set_xlabel("txn_id")
ax3.set_ylabel("txn_amount")


 # Add legend to distinguish different customers

  # Adjust layout to prevent overlap

customers_to_plot = ["Johnny Awesome", "Bob Marley", "Taylor Swift"]
colors = ['r', 'g', 'b']  # Specify colors for each customer
for customer, color in zip(customers_to_plot, colors):
    ax4.plot(df[df["Customers"] == customer]["txn_id"], df[df["Customers"] == customer]["txn_total"], color + '--*', label=customer)

ax4.set_title("Selected Customers Spending")
ax4.set_xlabel("txn_id")
ax4.set_ylabel("txn_amount")
# Out:
# Text(0, 0.5, 'txn_amount')

# %%
"Johnny Awesome","Taylor Swift","Bob Marley

# %%
for customer in df["Customers"].unique():
    ax4.plot(df[df["Customers"] == customer]["txn_id"], df[df["Customers"] == customer]["txn_total"],)

ax4.set_title("All Customers Spending")
ax4.set_xlabel("txn_id")
ax4.set_ylabel("txn_amount")
# Out:
# Text(24.000000000000007, 0.5, 'txn_amount')

# %%
df.groupby('Category').aggregate({'txn_total':'sum'}, ascending=False)
# Out:
#                   txn_total
# Category
# hnw                 1564.84
# personal_banking    3445.79
# wealth              2037.46

# %%
import matplotlib.pyplot as plt

# Group by 'Category' and sum 'txn_total' for each category
category_totals = df.groupby('Category').agg({'txn_total': 'sum'})

# Sort the DataFrame by the sum of 'txn_total' in descending order
category_totals_sorted = category_totals.sort_values(by='txn_total')

# Plot the sorted DataFrame as a bar graph
category_totals_sorted.plot(kind='bar')

# Set plot title and labels
plt.title('Total Transaction Amount by Category')
plt.xlabel('Category')
plt.ylabel('Total Transaction Amount')


plt.show()

# %%
sorted_df = df.groupby('Category').aggregate({'txn_total':'sum'}).sort_values(by='txn_total', ascending=False)

# %%
amts = sorted_df['txn_total']

# %%
for i, each_amt in emulater(amts):
    plt.text(i,each_amt, str(each_amt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 for i, each_amt in emulater(amts):
#       2     plt.text(i,each_amt, str(each_amt))
#
# NameError: name 'emulater' is not defined

# %%
import matplotlib.pyplot as plt

# Group by 'Category' and sum 'txn_total' for each category
category_totals = df.groupby('Category').agg({'txn_total': 'sum'})

# Sort the DataFrame by the sum of 'txn_total' in descending order
category_totals_sorted = category_totals.sort_values(by='txn_total', ascending=False)

# Plot the sorted DataFrame as a bar graph
ax = category_totals_sorted.plot(kind='bar')

# Set plot title and labels
ax.set_title('Total Transaction Amount by Category')
ax.set_xlabel('Category')
ax.set_ylabel('Total Transaction Amount')

# Annotate each bar with its respective value
for i, v in enumerate(category_totals_sorted['txn_total']):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Banking categiry, find the total amount paid vai each payment methode

# %%
import matplotlib.pyplot as plt


             
for i, v in enumerate(each_amt['txn_total']):
    ax.text(i, v, str(v), ha='center', va='bottom')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 5
#       1 import matplotlib.pyplot as plt
# ----> 5 for i, v in enumerate(each_amt['txn_total']):
#       6     ax.text(i, v, str(v), ha='center', va='bottom')
#
# TypeError: 'float' object is not subscriptable

# %%
df.groupby(['Category', 'txn_type']).aggregate({'txn_total': 'sum'})
# Out:
#                            txn_total
# Category         txn_type
# hnw              Cash         652.01
#                  Credit       451.15
#                  Debit        461.68
# personal_banking Cash         961.75
#                  Credit       815.55
#                  Debit       1668.49
# wealth           Cash         391.13
#                  Credit       595.64
#                  Debit       1050.69

# %%
df.groupby(['Category', 'txn_type']).aggregate({'txn_total': 'sum'}).unstack('txn_type')
# Out:
#                  txn_total
# txn_type              Cash  Credit    Debit
# Category
# hnw                 652.01  451.15   461.68
# personal_banking    961.75  815.55  1668.49
# wealth              391.13  595.64  1050.69

# %%
df.groupby(['Category', 'txn_type']).aggregate({'txn_total': 'sum'}).unstack('txn_type').plot(kind='bar',stacked =True)
# Out:
# <Axes: xlabel='Category'>
